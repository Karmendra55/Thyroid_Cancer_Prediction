# %%
# Core Libraries
import pandas as pd
import numpy as np
import shap
import joblib
import warnings 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score)
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.calibration import calibration_curve
from sklearn.feature_selection import RFE

from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

warnings.filterwarnings("ignore")

# %%
# Load dataset
df = pd.read_csv("../dataset/dataset.csv")
print(f"✅ Dataset Loaded Successfully. Shape: {df.shape}")

# Preview dataset
df.head()
# Out:
# ✅ Dataset Loaded Successfully. Shape: (383, 17)
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# ...

# %%
# Check for nulls
print("\nMissing Values per Column:")
print(df.isnull().sum())

# Summary statistics
df.describe(include='all').T
# Out:
# Missing Values per Column:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64
#                       count unique                  top freq       mean  \
# Age                   383.0    NaN                  NaN  NaN  40.866841
# Gender                  383      2                    F  312        NaN
# Smoking                 383      2                   No  334        NaN
# Hx Smoking              383      2                   No  355        NaN
# Hx Radiothreapy         383      2                   No  376        NaN
# ...

# %%
df['HighRisk'] = df.apply(
    lambda row: 1 if row['Stage'] in ['IVA', 'IVB'] or row['M'] == 'M1' else 0, axis=1
)
print("\nHighRisk distribution:")
print(df["HighRisk"].value_counts(normalize=True))
# Out:
# HighRisk distribution:
# HighRisk
# 0    0.942559
# 1    0.057441
# Name: proportion, dtype: float64

# %%
# Encode categorical features
le_dict = {}
for col in df.select_dtypes(include="object").columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    le_dict[col] = le

# %%
# Define input features (X) and target (y)
X = df.drop(['Recurred', 'HighRisk'], axis=1)
y = df['Recurred']
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

print(f"\nAfter SMOTE: {X_res.shape}, target distribution:")
print(pd.Series(y_res).value_counts(normalize=True))
# Out:
# After SMOTE: (550, 16), target distribution:
# Recurred
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
print("X columns:", X.shape[1])
print("y name:", y.name)
# Out:
# X columns: 16
# y name: Recurred

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42
)

print(f"\nTrain shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (440, 16), Test shape: (110, 16)

# %%
# Testing and Training Model
models = {
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric="logloss", random_state=42),
    "LightGBM": LGBMClassifier(random_state=42),
}

results = []
trained_models = {}

for name, mdl in models.items():
    mdl.fit(X_train, y_train)
    y_pred = mdl.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    print(f"\n📊 {name} Report:")
    print(classification_report(y_test, y_pred))

    results.append([name, acc, roc_auc])
    trained_models[name] = mdl
# Out:
# 📊 RandomForest Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        59
#            1       0.98      1.00      0.99        51
#
#     accuracy                           0.99       110
#    macro avg       0.99      0.99      0.99       110
# weighted avg       0.99      0.99      0.99       110
#
#
# 📊 XGBoost Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        59
#            1       0.93      1.00      0.96        51
#
#     accuracy                           0.96       110
#    macro avg       0.96      0.97      0.96       110
# weighted avg       0.97      0.96      0.96       110
#
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 224, number of negative: 216
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000409 seconds.
# ...

# %%
# Compare results
results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "ROC_AUC"])
print("\nModel comparison:")
print(results_df.sort_values("ROC_AUC", ascending=False))
# Out:
# Model comparison:
#           Model  Accuracy   ROC_AUC
# 0  RandomForest  0.990909  0.991525
# 1       XGBoost  0.963636  0.966102
# 2      LightGBM  0.963636  0.966102

# %%
best_name = results_df.sort_values("ROC_AUC", ascending=False).iloc[0]["Model"]
best_model = trained_models[best_name]
print("Best Model:", best_model)
# Out:
# Best Model: RandomForestClassifier(random_state=42)

# %%
# Gender vs Recurrence
plt.figure(figsize=(6,4))
sns.countplot(x="Gender", hue="Recurred", data=df, palette="pastel")
plt.title("Cancer Recurrence by Gender")
plt.show()

# %%
# Age distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=20, kde=True, color="teal")
plt.title("Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# Stage vs Recurrence
plt.figure(figsize=(8,5))
sns.countplot(x="Stage", hue="Recurred", data=df, palette="muted")
plt.title("Recurrence by Stage")
plt.show()

# %%
plt.figure(figsize=(8,6))

for name, model in models.items():
    y_pred = model.predict(X_test)
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)
    plt.plot(fpr, tpr, lw=2, label=f"{name} (AUC={roc_auc:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix (XGBoost)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,5))

sns.countplot(x=y, ax=ax[0], palette="pastel")
ax[0].set_title("Original Class Distribution")
ax[0].set_xlabel("Recurred")
ax[0].set_ylabel("Count")

sns.countplot(x=y_res, ax=ax[1], palette="muted")
ax[1].set_title("Balanced Class Distribution (After SMOTE)")
ax[1].set_xlabel("Recurred")
ax[1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df[['Age', 'T', 'N', 'M', 'Stage', 'Recurred']], hue="Recurred", palette="husl")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

y_pred_proba = model.predict_proba(X_test)[:,1]
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
ap = average_precision_score(y_test, y_pred_proba)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, marker='.', label=f'XGBoost (AP={ap:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

# %%
y_pred_proba = model.predict_proba(X_test)[:, 1]

# 3️⃣ Compute calibration curve
prob_true, prob_pred = calibration_curve(y_test, y_pred_proba, n_bins=10)

# 4️⃣ Plot
plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label="RandomForest")
plt.plot([0, 1], [0, 1], 'k--', label="Perfectly Calibrated")
plt.xlabel("Mean Predicted Probability")
plt.ylabel("Fraction of Positives")
plt.title("Calibration Curve")
plt.legend()
plt.show()

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar")
shap.summary_plot(shap_values, X_test)

# %%
# Saving the best model
FEATURES = X.columns.to_list()
joblib.dump((best_model, FEATURES), f"../trained_model/thyroid_recurrence_rf.pkl")

print(f"\n✅ Saved best model: {best_name}")
# Out:
# ✅ Saved best model: RandomForest

# %%
print("n_features_in_ (model):", model.n_features_in_)
print("training columns:", model.feature_names_in_)
# Out:
# n_features_in_ (model): 10
# training columns: ['Age' 'Thyroid_Function' 'Physical_Examination' 'Adenopathy' 'Focality'
#  'Risk' 'T' 'N' 'Stage' 'Response']
